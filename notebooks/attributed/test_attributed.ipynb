# %%
include("../../src/attributed/readAttributed.jl")
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at readAttributed.jl:10
# └ @ Core C:\Users\Leo Huang\Desktop\learning_to_cluster\src\attributed\readAttributed.jl:10
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at readAttributed.jl:11
# └ @ Core C:\Users\Leo Huang\Desktop\learning_to_cluster\src\attributed\readAttributed.jl:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at readAttributed.jl:116
# └ @ Core C:\Users\Leo Huang\Desktop\learning_to_cluster\src\attributed\readAttributed.jl:116
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at readAttributed.jl:119
# ...

# %% [markdown]
# ### Reddit Hyperlinks Body Dataset Info
#
# 286561

# %%
uu = unionDict()
# Out:
# Dict{Any,Any} with 35776 entries:
#   "weeklyplanetpodcast"  => ["sanspantsradio"]
#   "askgaymen"            => ["lgbteens"]
#   "canwc"                => ["homestuck"]
#   "pharmastock"          => ["wallstreetbets"]
#   "everyadultshouldknow" => ["entrepreneur"]
#   "knockedoffhighhorse"  => ["writingprompts"]
#   "dawnbreakerstory"     => ["fantasywriters"]
#   "redditfreeze"         => ["redditillusion"]
#   "nautiluscoin"         => ["dogemarket" "dogecoin"]
#   "modelforeignaffairs"  => ["modelinfowars"]
#   "berntheconvention"    => ["blackout2015" "sandersforpresident" … "subredditd…
#   "webmoney"             => ["scams"]
#   "googleglass"          => ["humanfanclub"]
#   "badneighbor"          => ["ark_pc" "playarkservers" "playark" "survivetogeth…
#   "gout"                 => ["tacsuncensored"]
#   "bpdsoffa"             => ["abuseinterrupted" "bpdlovedones" "relationships"]
#   "sexclusiveselling"    => ["ytowel" "rebeccastilles69"]
# ...

# %%
d = getDict(body)
# Out:
# Dict{Int64,String} with 35776 entries:
#   15769 => "centrist"
#   13575 => "jacksfilms"
#   35510 => "ww2"
#   10094 => "tonr"
#   22035 => "theehive"
#   6265  => "nms_federation"
#   30216 => "estp"
#   32373 => "ceretropic"
#   34034 => "txrangersexperience"
#   9934  => "sydneyswans"
#   21807 => "sqlserver"
#   8805  => "smiteart"
#   29201 => "chicagoproducers"
#   1333  => "a858de45f56d9bc9"
#   13120 => "mancudi"
#   3120  => "uwaterloosimulator"
#   9911  => "underdoggame"
#   11942 => "moviedicks"
#   20368 => "sideloaded"
#   19698 => "throwers"
#   29981 => "olympianregion"
#   10458 => "deadlypremonition"
#   16429 => "sonicshowerthoughts"
#   32855 => "vikings_tvseries"
#   7237  => "einfach_posten"
#   ⋮     => ⋮

# %%
body_prop_array
# Out:
# 286561×11 Array{Float64,2}:
#   345.0   298.0  0.756522  0.0173913    …    57.0   53.0   10.0  4.78947
#   101.0    98.0  0.742574  0.019802          14.0   14.0    2.0  5.71429
#    85.0    85.0  0.752941  0.0235294         10.0   10.0    2.0  7.2
#  1124.0   949.0  0.772242  0.00177936       191.0  125.0   34.0  4.62304
#   715.0   622.0  0.777622  0.00699301       119.0   92.0   22.0  4.80672
#  1328.0  1110.0  0.768825  0.0143072    …   234.0  160.0   39.0  4.49573
#   184.0   172.0  0.744565  0.0326087         23.0   23.0    5.0  6.56522
#   295.0   256.0  0.749153  0.020339          51.0   48.0    7.0  4.66667
#  3927.0  3488.0  0.719888  0.0229183        612.0  248.0  111.0  4.8219
#  3927.0  3488.0  0.719888  0.0229183        612.0  248.0  111.0  4.8219
#  2849.0  2467.0  0.704107  0.00737101   …   425.0  270.0   93.0  4.82353
#  3455.0  3095.0  0.709407  0.0274964        529.0  231.0  105.0  4.86578
#  3455.0  3095.0  0.709407  0.0274964        529.0  231.0  105.0  4.86578
# ...

# %%
body_properties
# Out:
# 286561×11 DataFrame. Omitted printing of 5 columns
# │ Row    │ x1      │ x2      │ x3       │ x4          │ x5        │ x6        │
# │        │ Float64 │ Float64 │ Float64  │ Float64     │ Float64   │ Float64   │
# ├────────┼─────────┼─────────┼──────────┼─────────────┼───────────┼───────────┤
# │ 1      │ 345.0   │ 298.0   │ 0.756522 │ 0.0173913   │ 0.0869565 │ 0.150725  │
# │ 2      │ 101.0   │ 98.0    │ 0.742574 │ 0.019802    │ 0.049505  │ 0.0594059 │
# │ 3      │ 85.0    │ 85.0    │ 0.752941 │ 0.0235294   │ 0.0823529 │ 0.0117647 │
# │ 4      │ 1124.0  │ 949.0   │ 0.772242 │ 0.00177936  │ 0.0578292 │ 0.179715  │
# │ 5      │ 715.0   │ 622.0   │ 0.777622 │ 0.00699301  │ 0.0251748 │ 0.145455  │
# │ 6      │ 1328.0  │ 1110.0  │ 0.768825 │ 0.0143072   │ 0.0753012 │ 0.180723  │
# │ 7      │ 184.0   │ 172.0   │ 0.744565 │ 0.0326087   │ 0.0380435 │ 0.0815217 │
# │ 8      │ 295.0   │ 256.0   │ 0.749153 │ 0.020339    │ 0.0271186 │ 0.142373  │
# ...

# %%
(from, to) = getBodyNumericalLabel()
# Out:
# ([19809, 21920, 25674, 12931, 1194, 32810, 33608, 34493, 23728, 23728  …  21032, 6735, 7183, 34780, 13872, 13872, 25223, 11611, 21209, 15907], [10589, 22058, 4618, 14118, 11655, 28499, 16219, 30007, 1493, 2427  …  19918, 28178, 34462, 1778, 5750, 24912, 27619, 179, 10126, 6338])

# %%
from
# Out:
# 286561-element Array{Int64,1}:
#  19809
#  21920
#  25674
#  12931
#   1194
#  32810
#  33608
#  34493
#  23728
#  23728
#  16235
#   4847
#   4847
#      ⋮
#   7059
#  17881
#  21032
#   6735
#   7183
#  34780
#  13872
#  13872
#  25223
#  11611
#  21209
#  15907

# %%
to
# Out:
# 286561-element Array{Int64,1}:
#  10589
#  22058
#   4618
#  14118
#  11655
#  28499
#  16219
#  30007
#   1493
#   2427
#   6671
#   1493
#   2427
#      ⋮
#  15667
#  29312
#  19918
#  28178
#  34462
#   1778
#   5750
#  24912
#  27619
#    179
#  10126
#   6338

# %%
wa = getBodyWeightedAdj()
# Out:
# 35776×35776 SparseMatrixCSC{Float64,Int64} with 248660 stored entries:
#   [22052,     1]  =  1.0
#   [5386 ,     2]  =  3.0
#   [34462,     3]  =  2.0
#   [20356,     4]  =  1.0
#   [20356,     5]  =  1.0
#   [25386,     5]  =  1.0
#   [28499,     6]  =  3.0
#   [32810,     6]  =  3.0
#   [13686,     7]  =  1.0
#   [1894 ,     8]  =  1.0
#   [4163 ,     9]  =  2.0
#   [4236 ,     9]  =  2.0
#   ⋮
#   [19988, 35772]  =  1.0
#   [4027 , 35773]  =  1.0
#   [5262 , 35773]  =  2.0
#   [5727 , 35773]  =  1.0
#   [26721, 35773]  =  1.0
#   [27327, 35773]  =  1.0
#   [31754, 35773]  =  1.0
#   [3314 , 35774]  =  1.0
#   [20656, 35775]  =  1.0
#   [1778 , 35776]  =  1.0
#   [6361 , 35776]  =  1.0
#   [13530, 35776]  =  1.0
#   [14253, 35776]  =  1.0

# %%
ba = getBodyAttributeAdj()
# Out:
# 35776×35776 SparseMatrixCSC{Array{T,1} where T<:Real,Int64} with 137821 stored entries:
#   [5386 ,     2]  =  [7939.0, 6642.0, 0.785615, 0.00176345, 0.0263257, 0.172944, 0.0396775, 1369.0, 555.0, 255.0, 4.58729]
#   [34462,     3]  =  [1053.0, 948.0, 1.50531, 0.0510464, 0.0972746, 0.218268, 0.225372, 159.0, 115.0, 27.0, 10.4052]
#   [20356,     4]  =  [197.0, 189.0, 0.725888, 0.0203046, 0.071066, 0.0558376, 0.19797, 26.0, 24.0, 5.0, 5.88462]
#   [25386,     5]  =  [22022.0, 18017.0, 0.78081, 0.000681137, 0.0144401, 0.186859, 0.0316502, 4052.0, 1237.0, 622.0, 4.26851]
#   [1894 ,     8]  =  [4600.0, 4302.0, 0.751739, 0.0297826, 0.0130435, 0.0754348, 0.143043, 597.0, 304.0, 144.0, 6.38526]
#   [193  ,    13]  =  [986.0, 871.0, 0.771805, 0.015213, 0.0172414, 0.119675, 0.0933063, 156.0, 113.0, 40.0, 5.09615]
#   [740  ,    13]  =  [187.0, 170.0, 0.775401, 0.0213904, 0.0481283, 0.106952, 0.0962567, 29.0, 25.0, 7.0, 5.24138]
# ...
